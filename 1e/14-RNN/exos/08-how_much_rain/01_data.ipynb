# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
p_dataset = Path("~/datasets/kaggle/how-much-did-it-rain-ii")
p_train = p_dataset / "train.zip"
p_train
# Out:
# PosixPath('~/datasets/kaggle/how-much-did-it-rain-ii/train.zip')

# %%
train_df = pd.read_csv(p_train)
train_df
# Out:
#                Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  \
# 0               1             3          10.0   NaN           NaN
# 1               1            16          10.0   NaN           NaN
# 2               1            25          10.0   NaN           NaN
# 3               1            35          10.0   NaN           NaN
# 4               1            45          10.0   NaN           NaN
# ...           ...           ...           ...   ...           ...
# 13765196  1180945            38           9.0  33.0          19.5
# 13765197  1180945            42           9.0  33.0          21.0
# 13765198  1180945            47           9.0  29.5          10.0
# 13765199  1180945            52           9.0  19.0           NaN
# 13765200  1180945            57           9.0   7.5           NaN
#
#           Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# 0                  NaN           NaN           NaN                    NaN
# ...
